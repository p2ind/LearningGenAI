# %% [markdown]
# # Python Requirements
# ---

# %% [markdown]
# ## We are going to cover python requirement

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Welcome to Python programming.")
# Out:
# Welcome to Python programming.
